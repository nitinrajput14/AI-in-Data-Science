# %% [markdown]
# ***Basic of python***

# %% [markdown]
# **INTEGER**

# %%
 age= 21   #numbers that we provide dicectly are called integers in common language
 num = 22
 print(age)
print(type(age))  #which type of datatype is age
# Out:
# 21
# <class 'int'>

# %%
name = "Welcome to Python"          # " " in double quotes strings are the data types
print(''' "Welcome to Python" ''')
print(type(name))  #class string
# Out:
#  "Welcome to Python"
# <class 'str'>

# %%
print(""" "Welcome to Python" """)  #using triple quotes to print single or double quotes inside
# Out:
#  "Welcome to Python"

# %% [markdown]
# #Float

# %%
marks = 23.34 #floats are integers with decimal point

# %% [markdown]
# #SUM

# %%
print(10+5)
# Out:
# 15

# %%
n1 = 10.9
n2 = 9.5
print(n1+n2)  #output is 16.7 , it is a float number
# Out:
# 20.4

# %%
sum = n1+n2
print(sum)   #print of sum variable which we can do directly
# Out:
# 20.4

# %% [markdown]
# #Comments

# %%
""" Nitin
    Rajput """    #comments are those lines who do not interfere with code and \
                #can be written inside code to increase understanding of code
# Out:
# ' Nitin\n    Rajput '

# %% [markdown]
# #Floor division

# %%
print(16/10)  #it shows output in float
print(16//10) #floor divison gives the output round to nearest whole no. print left side of decimal
# Out:
# 1.6
# 1

# %% [markdown]
# #Relational Operator

# %%
num1 = 1
num2 = 2
print(num1 == num2)  #is num1 is same as num 2
print(num1 != num2)  # is num 1 is not equal to num 2
print(num1 <= num2)  # is num 1 is lessthan equal to num 2
print(num1 >= num2)  #is num 1 is greaterthan equal to num 2
print(num1 < num2)  #is num 1 is less than to num 2
print(num1 > num2)  #is num 1 is greater than to num 2
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# #Assignment Operators

# %%
age = 20 #Assigns the address of the value to the variable

# %% [markdown]
# #Logical Operators => and, or, not

# %%
print(True and True)  #Both condition have to true
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True or True)  #Atleast one condition have to true
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print( not True)  #Reverse the condition means nottrue is false to it means false
print( not False)
print( not True)
print( not False)
# Out:
# False
# True
# False
# True

# %%
n1 = 7
print(type(n1))  #prints the type of data type
# Out:
# <class 'int'>

# %% [markdown]
# #Input

# %%
name = input("Enter Your Name:")  #gets the input from the user
age = int(input("Enter Your Age:"))  #gets input as a integer
print(name,age)        #prints the output
# Out:
# Enter Your Name:Nitin Rajput
# Enter Your Age:20
# Nitin Rajput 20

# %% [markdown]
# #Q. Print Area of Square

# %%
A = int(input("Enter length of one side of sqr:"))    #takes input as sq. length
area = A*A    #formula of area of sq.
print(f"Area of square: {area}")  #use f" " as to input variable in a line with some information
print("Area of square:",area)
# Out:
# Enter length of one side of sqr:100
# Area of square: 10000
# Area of square: 10000
